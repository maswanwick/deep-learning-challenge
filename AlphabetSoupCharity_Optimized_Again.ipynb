# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns=['EIN', 'NAME'], inplace=True)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Remove STATUS and SPECIAL_CONSIDERATIONS columns since they are not beneficial (.01% and .08% variation, respectively)

# display STATUS values
print(application_df['STATUS'].value_counts())

# display SPECIAL_CONSIDERATIONS values
print(application_df['SPECIAL_CONSIDERATIONS'].value_counts())

# Drop the columns
application_df.drop(columns=['STATUS', 'SPECIAL_CONSIDERATIONS'], inplace=True)
# Out:
# 1    34294
# 0        5
# Name: STATUS, dtype: int64
# N    34272
# Y       27
# Name: SPECIAL_CONSIDERATIONS, dtype: int64

# %%
# Create two categories (bins) for ASK_AMT; 5000 and >5000

# Get the maximum value for our upper bound
max_amt = application_df['ASK_AMT'].max()

# Create two bins - 0-5000 and >5000
application_df['ASK_AMT_CATEGORY'] = pd.cut(application_df['ASK_AMT'], [0, 5000, max_amt], labels=['5000', '>5000'])

# Drop original ASK_AMT column
application_df.drop(columns=['ASK_AMT'], inplace=True)

# Display the ASK_AMT_CATEGORY distribution
application_df['ASK_AMT_CATEGORY'].value_counts()
# Out:
# 5000     25398
# >5000     8901
# Name: ASK_AMT_CATEGORY, dtype: int64

# %%
# Re-display the unique values in each column
application_df.nunique()
# Out:
# APPLICATION_TYPE    17
# AFFILIATION          6
# CLASSIFICATION      71
# USE_CASE             5
# ORGANIZATION         4
# INCOME_AMT           9
# IS_SUCCESSFUL        2
# ASK_AMT_CATEGORY     2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df.value_counts('APPLICATION_TYPE')
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T29        2
# T15        2
# T17        1
# dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

# Create a DataFrame grouped by APPLICATION_TYPE
app_types_df = application_df.groupby(['APPLICATION_TYPE'])[['APPLICATION_TYPE']].count()

# Select the APPLICATION_TYPE records with a count less than 500
application_types_to_replace = list(app_types_df.loc[app_types_df['APPLICATION_TYPE'] < 2000].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     7262
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_value_counts = application_df.value_counts('CLASSIFICATION')
classification_value_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2190        1
# C2380        1
# C2500        1
# C2561        1
# C8210        1
# Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_value_counts[classification_value_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C2710        3
# C1260        3
# C0           3
# C1267        2
# C1246        2
# C1256        2
# C3200        2
# C1234        2
# dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

# Create a DataFrame grouped by CLASSIFICATION
classification_df = application_df.groupby(['CLASSIFICATION'])[['CLASSIFICATION']].count()

# Select the CLASSIFICATION records with a count less than 1000
classifications_to_replace = list(classification_df.loc[classification_df['CLASSIFICATION'] < 10000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# Other    16973
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_vals_df = pd.get_dummies(application_df, columns=['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'ASK_AMT_CATEGORY'])

# %%
# Split our preprocessed data into our features and target arrays

# Get the feature columns; all columns except our target (IS_SUCCESSFUL)
feature_cols = application_vals_df.columns.drop('IS_SUCCESSFUL')

# Get target set
y = application_vals_df['IS_SUCCESSFUL'].values

# Get feature set
X = application_vals_df[feature_cols].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 80
hidden_nodes_layer3 = 80

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                2480
#
#  dense_1 (Dense)             (None, 80)                6480
#
#  dense_2 (Dense)             (None, 80)                6480
#
#  dense_3 (Dense)             (None, 1)                 81
#
# =================================================================
# Total params: 15521 (60.63 KB)
# Trainable params: 15521 (60.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=300)
# Out:
# Epoch 1/300
# 965/965 [==============================] - 3s 2ms/step - loss: 0.6007 - accuracy: 0.6968
# Epoch 2/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5928 - accuracy: 0.7017
# Epoch 3/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5916 - accuracy: 0.7038
# Epoch 4/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5902 - accuracy: 0.7039
# Epoch 5/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5899 - accuracy: 0.7059
# Epoch 6/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5892 - accuracy: 0.7060
# Epoch 7/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5884 - accuracy: 0.7065
# Epoch 8/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5881 - accuracy: 0.7069
# Epoch 9/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5873 - accuracy: 0.7084
# Epoch 10/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5875 - accuracy: 0.7079
# Epoch 11/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5869 - accuracy: 0.7084
# Epoch 12/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5867 - accuracy: 0.7081
# Epoch 13/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5865 - accuracy: 0.7085
# Epoch 14/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5863 - accuracy: 0.7080
# Epoch 15/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5860 - accuracy: 0.7088
# Epoch 16/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5857 - accuracy: 0.7086
# Epoch 17/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5853 - accuracy: 0.7091
# Epoch 18/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5853 - accuracy: 0.7080
# Epoch 19/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5852 - accuracy: 0.7098
# Epoch 20/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5853 - accuracy: 0.7089
# Epoch 21/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5850 - accuracy: 0.7092
# Epoch 22/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5851 - accuracy: 0.7097
# Epoch 23/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5847 - accuracy: 0.7091
# Epoch 24/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5847 - accuracy: 0.7094
# Epoch 25/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5843 - accuracy: 0.7101
# Epoch 26/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5844 - accuracy: 0.7098
# Epoch 27/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5845 - accuracy: 0.7091
# Epoch 28/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5842 - accuracy: 0.7086
# Epoch 29/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5839 - accuracy: 0.7096
# Epoch 30/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5839 - accuracy: 0.7096
# Epoch 31/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5836 - accuracy: 0.7099
# Epoch 32/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5837 - accuracy: 0.7101
# Epoch 33/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5833 - accuracy: 0.7095
# Epoch 34/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5835 - accuracy: 0.7094
# Epoch 35/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5831 - accuracy: 0.7105
# Epoch 36/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5832 - accuracy: 0.7105
# Epoch 37/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5827 - accuracy: 0.7103
# Epoch 38/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5832 - accuracy: 0.7095
# Epoch 39/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5833 - accuracy: 0.7110
# Epoch 40/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5826 - accuracy: 0.7108
# Epoch 41/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5827 - accuracy: 0.7098
# Epoch 42/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5827 - accuracy: 0.7108
# Epoch 43/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5821 - accuracy: 0.7111
# Epoch 44/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5823 - accuracy: 0.7110
# Epoch 45/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5824 - accuracy: 0.7105
# Epoch 46/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5820 - accuracy: 0.7108
# Epoch 47/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5823 - accuracy: 0.7100
# Epoch 48/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5820 - accuracy: 0.7109
# Epoch 49/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7105
# Epoch 50/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7108
# Epoch 51/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5817 - accuracy: 0.7109
# Epoch 52/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7109
# Epoch 53/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5818 - accuracy: 0.7101
# Epoch 54/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5817 - accuracy: 0.7097
# Epoch 55/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5815 - accuracy: 0.7109
# Epoch 56/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5817 - accuracy: 0.7102
# Epoch 57/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5813 - accuracy: 0.7111
# Epoch 58/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5811 - accuracy: 0.7113
# Epoch 59/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5812 - accuracy: 0.7115
# Epoch 60/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5810 - accuracy: 0.7111
# Epoch 61/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5810 - accuracy: 0.7118
# Epoch 62/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5810 - accuracy: 0.7110
# Epoch 63/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5811 - accuracy: 0.7111
# Epoch 64/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5810 - accuracy: 0.7107
# Epoch 65/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5807 - accuracy: 0.7116
# Epoch 66/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5805 - accuracy: 0.7117
# Epoch 67/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5810 - accuracy: 0.7117
# Epoch 68/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5809 - accuracy: 0.7115
# Epoch 69/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5804 - accuracy: 0.7118
# Epoch 70/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5805 - accuracy: 0.7113
# Epoch 71/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5809 - accuracy: 0.7122
# Epoch 72/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5806 - accuracy: 0.7116
# Epoch 73/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5807 - accuracy: 0.7123
# Epoch 74/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5804 - accuracy: 0.7122
# Epoch 75/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5807 - accuracy: 0.7122
# Epoch 76/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7117
# Epoch 77/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5804 - accuracy: 0.7118
# Epoch 78/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5811 - accuracy: 0.7117
# Epoch 79/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5805 - accuracy: 0.7121
# Epoch 80/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5806 - accuracy: 0.7117
# Epoch 81/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7120
# Epoch 82/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7117
# Epoch 83/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5807 - accuracy: 0.7118
# Epoch 84/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7116
# Epoch 85/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5805 - accuracy: 0.7113
# Epoch 86/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5797 - accuracy: 0.7127
# Epoch 87/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5802 - accuracy: 0.7117
# Epoch 88/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7123
# Epoch 89/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7116
# Epoch 90/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7113
# Epoch 91/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7119
# Epoch 92/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5803 - accuracy: 0.7118
# Epoch 93/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5800 - accuracy: 0.7124
# Epoch 94/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5799 - accuracy: 0.7118
# Epoch 95/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7122
# Epoch 96/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7123
# Epoch 97/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7120
# Epoch 98/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5816 - accuracy: 0.7117
# Epoch 99/300
# 965/965 [==============================] - 3s 4ms/step - loss: 0.5797 - accuracy: 0.7122
# Epoch 100/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7120
# Epoch 101/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5798 - accuracy: 0.7119
# Epoch 102/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7118
# Epoch 103/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7115
# Epoch 104/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5799 - accuracy: 0.7123
# Epoch 105/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5795 - accuracy: 0.7123
# Epoch 106/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5795 - accuracy: 0.7125
# Epoch 107/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5798 - accuracy: 0.7121
# Epoch 108/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5795 - accuracy: 0.7120
# Epoch 109/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7121
# Epoch 110/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7119
# Epoch 111/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5800 - accuracy: 0.7117
# Epoch 112/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5796 - accuracy: 0.7123
# Epoch 113/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5798 - accuracy: 0.7120
# Epoch 114/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7124
# Epoch 115/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7120
# Epoch 116/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7120
# Epoch 117/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7119
# Epoch 118/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5796 - accuracy: 0.7125
# Epoch 119/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5799 - accuracy: 0.7117
# Epoch 120/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7120
# Epoch 121/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7120
# Epoch 122/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7122
# Epoch 123/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7119
# Epoch 124/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7120
# Epoch 125/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5796 - accuracy: 0.7124
# Epoch 126/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7121
# Epoch 127/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5931 - accuracy: 0.7116
# Epoch 128/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5795 - accuracy: 0.7120
# Epoch 129/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7116
# Epoch 130/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5789 - accuracy: 0.7124
# Epoch 131/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5792 - accuracy: 0.7124
# Epoch 132/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5798 - accuracy: 0.7121
# Epoch 133/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7126
# Epoch 134/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7123
# Epoch 135/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5795 - accuracy: 0.7122
# Epoch 136/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7125
# Epoch 137/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5805 - accuracy: 0.7118
# Epoch 138/300
# 965/965 [==============================] - 4s 4ms/step - loss: 0.5796 - accuracy: 0.7119
# Epoch 139/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7119
# Epoch 140/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5801 - accuracy: 0.7120
# Epoch 141/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7120
# Epoch 142/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5798 - accuracy: 0.7121
# Epoch 143/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7121
# Epoch 144/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.
300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5790 - accuracy: 0.7125
# Epoch 233/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5792 - accuracy: 0.7123
# Epoch 234/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5790 - accuracy: 0.7124
# Epoch 235/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5795 - accuracy: 0.7126
# Epoch 236/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7129
# Epoch 237/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7123
# Epoch 238/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7123
# Epoch 239/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5793 - accuracy: 0.7123
# Epoch 240/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5795 - accuracy: 0.7117
# Epoch 241/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7128
# Epoch 242/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7121
# Epoch 243/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7120
# Epoch 244/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7123
# Epoch 245/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5811 - accuracy: 0.7121
# Epoch 246/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5790 - accuracy: 0.7125
# Epoch 247/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5787 - accuracy: 0.7123
# Epoch 248/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7127
# Epoch 249/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7125
# Epoch 250/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7120
# Epoch 251/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7122
# Epoch 252/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5791 - accuracy: 0.7125
# Epoch 253/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7124
# Epoch 254/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7125
# Epoch 255/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7116
# Epoch 256/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7128
# Epoch 257/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5790 - accuracy: 0.7125
# Epoch 258/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5798 - accuracy: 0.7123
# Epoch 259/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5787 - accuracy: 0.7119
# Epoch 260/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5787 - accuracy: 0.7125
# Epoch 261/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7126
# Epoch 262/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7121
# Epoch 263/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5797 - accuracy: 0.7120
# Epoch 264/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5801 - accuracy: 0.7122
# Epoch 265/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5810 - accuracy: 0.7121
# Epoch 266/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7122
# Epoch 267/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7119
# Epoch 268/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7126
# Epoch 269/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7124
# Epoch 270/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5788 - accuracy: 0.7118
# Epoch 271/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5789 - accuracy: 0.7123
# Epoch 272/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7122
# Epoch 273/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5790 - accuracy: 0.7124
# Epoch 274/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5796 - accuracy: 0.7122
# Epoch 275/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5798 - accuracy: 0.7125
# Epoch 276/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5790 - accuracy: 0.7123
# Epoch 277/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5808 - accuracy: 0.7125
# Epoch 278/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7125
# Epoch 279/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7120
# Epoch 280/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5792 - accuracy: 0.7126
# Epoch 281/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5803 - accuracy: 0.7121
# Epoch 282/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5790 - accuracy: 0.7122
# Epoch 283/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5791 - accuracy: 0.7124
# Epoch 284/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5790 - accuracy: 0.7122
# Epoch 285/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7125
# Epoch 286/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7121
# Epoch 287/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7125
# Epoch 288/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7126
# Epoch 289/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5788 - accuracy: 0.7125
# Epoch 290/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7122
# Epoch 291/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5791 - accuracy: 0.7127
# Epoch 292/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7123
# Epoch 293/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5788 - accuracy: 0.7123
# Epoch 294/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7121
# Epoch 295/300
# 965/965 [==============================] - 3s 3ms/step - loss: 0.5824 - accuracy: 0.7119
# Epoch 296/300
# 965/965 [==============================] - 2s 3ms/step - loss: 0.5805 - accuracy: 0.7116
# Epoch 297/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5794 - accuracy: 0.7122
# Epoch 298/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5786 - accuracy: 0.7124
# Epoch 299/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5789 - accuracy: 0.7121
# Epoch 300/300
# 965/965 [==============================] - 2s 2ms/step - loss: 0.5786 - accuracy: 0.7119

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 108/108 - 0s - loss: 0.6110 - accuracy: 0.7122 - 311ms/epoch - 3ms/step
# Loss: 0.610990047454834, Accuracy: 0.7122448682785034

# %%
# Export our model to HDF5 file
nn.save(save_format='h5', filepath='AlphabetSoupCharity_Optimization_Again.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
